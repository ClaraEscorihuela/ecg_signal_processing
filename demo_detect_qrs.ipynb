# %%
from signal_processing import analyze_data, ecg_features, qrs_detection

import matplotlib
# %matplotlib notebook
import neurokit2 as nk
import numpy as np
import pandas as pd
import os

# %% [markdown]
# ### 1. QRS detection

# %%
patient = '001'           # Patient to analyze data
signal_to_present = 'i'  # Signal to show to the doctor
fs = 1000                 # Sample frequency
time_min_qrs = 0.06       # Minimum time for a qrs complex [1]
refractor_time = 0.2      # Minimum time between two qrs complexs [1]
th_grad = 0.075

# %%
wk_dir = os.getcwd()
path_name = f'{wk_dir}\\physionet.org\\files\\ptbdb\\1.0.0\\patient{patient}'

# Look for all the ecg files in one patient
files = [file for file in os.listdir(path_name) if 'xyz' in file]
files = np.unique(np.array([ file.split('.')[0] for file in files]))

# Create an object to save all waves from the same patient
waves = ecg_features.ecg_waves()

# Iterate over the ecg from one patient
for i, file in enumerate(files):
    if file == 'index':
        continue

    print(f'Patient number {patient}, ecg number {i}')

    # Extract data
    # signal_i to find the qrs complex, derivation 1 is the one used in this algorithm
    # signal_ii to find peaks, the one the doctor wants to see
    file = f'{path_name}\\{file}'
    df, col_names = analyze_data.upload_data(file)
    signal_ecg_i = analyze_data.select_derivation(df, col_names, der='i')
    signal_ecg_ii = analyze_data.select_derivation(df, col_names, der=signal_to_present)

    # Create object to find all features in an ecg
    wave_feat = ecg_features.ecg_wave(fs, signal_ecg_i, signal_ecg_ii)
    wave_feat.main_properties( fs=fs, t_qrs_min=time_min_qrs,  t_ref=refractor_time, th_grad=th_grad, plot = True)

    # Fill object with zeros in case the algorith does not work properly
    if type(wave_feat.periods) == bool:
        wave_feat.ecg_fix()

    # add ecg from the patient to the general object
    waves.add_wave(wave_feat)

print('yayy! We have it! ')
# Out:
# Patient number 001, ecg number 0
# avg =  7.177029872218235e-06
# <div id='c19d5fe6-f07f-4286-b5a7-3bf840b3fb7a'></div>
#  Heart rate = 82.8125 (beats/min)
# Heart rate periodicity = 0.7335 (mean seconds between beats)
# Heart rate variability = 0.00920271699010679 (std seconds between beats)
# Patient number 001, ecg number 1
# avg =  5.864781954041703e-06
# <div id='8e3a4185-baa1-45b6-bf7f-9f8ca20c9060'></div>
#  Heart rate = 86.45833333333333 (beats/min)
# Heart rate periodicity = 0.6956257668711657 (mean seconds between beats)
# Heart rate variability = 0.005270692076383867 (std seconds between beats)
# Patient number 001, ecg number 2
# avg =  -4.8425709291033166e-05
# <div id='2ecd1bc8-d756-4918-b31e-fceb27791b5e'></div>
#  Heart rate = 80.20833333333333 (beats/min)
# Heart rate periodicity = 0.7513774834437086 (mean seconds between beats)
# Heart rate variability = 0.00972383003184119 (std seconds between beats)
# yayy! We have it!

# %% [markdown]
# #### 2.1 Check the precision of the algorithm compare to neurokit2 library

# %%
# Select values to compare from one wave
for wave in waves.waves:
    ecg_signal_rdetection = wave.signal_1     # Select signal 2 because is the one we are showing to the doctor
    ecg_signal_peak_detection = wave.signal_2
    r_peaks_ind = wave.r_peaks_ind

    # apply the algorithm available in neurokit2 library to the same signal
    _, rpeaks = nk.ecg_peaks(ecg_signal_rdetection, sampling_rate=1000)
    rpeaks_ind = rpeaks['ECG_R_Peaks']

    # Calculate the difference in the number of r peaks
    print(f' Number of R peaks: Designed algorithm {len(r_peaks_ind)}, Neurokit2 {len(rpeaks_ind)}')
# Out:
#  Number of R peaks: Designed algorithm 170, Neurokit2 169
#  Number of R peaks: Designed algorithm 144, Neurokit2 144
#  Number of R peaks: Designed algorithm 151, Neurokit2 118

# %%
df_all_patients = pd.read_csv(f'{os.getcwd()}\\ecg_features_v12.csv')

# %%
# Error considering all patient
error_all_patients = df_all_patients['num_beats'] - df_all_patients['num beat neurokit2'].values

mean_error = np.mean(error_all_patients)
mean_abs_error = np.mean(abs(error_all_patients))
std_error = np.std(error_all_patients)
std_abs_error = np.std(abs(error_all_patients))

print(f'All patient: Mean error {mean_error} +- {std_error}')
print(f'All patient: Mean absolute error {mean_abs_error} +- {std_abs_error}')

# Error considering patients where the algorithm has worked
df_sub_patients = df_all_patients[df_all_patients["heart_rate"] > 0]
error_sub_patients = df_sub_patients['num_beats'] - df_sub_patients['num beat neurokit2']
# Out:
# All patient: Mean error -6.533962264150944 +- 31.730822128960163
# All patient: Mean absolute error 10.356603773584906 +- 30.69655508564476

# %%
# Error considering patients where the algorithm has worked
df_sub_patients = df_all_patients[df_all_patients["heart_rate"] > 0]
error_sub_patients = df_sub_patients['num_beats'] - df_sub_patients['num beat neurokit2']

mean_error_sub = np.mean(error_sub_patients)
mean_abs_error_sub = np.mean(abs(error_sub_patients))
std_error_sub = np.std(error_sub_patients)
std_abs_error_sub = np.std(abs(error_sub_patients))
print(f'Sub patient: Mean error {mean_error_sub} +- {std_error_sub}')
print(f'Sub patient: Mean absolute error {mean_abs_error_sub} +- {std_abs_error_sub}')
# Out:
# Sub patient: Mean error -1.9568627450980391 +- 20.040109338885713
# Sub patient: Mean absolute error 5.929411764705883 +- 19.242592607084276

# %%
wk_dir = os.getcwd()

df_save = pd.DataFrame()
patients = [patient[-3:] for patient in os.listdir(f'{wk_dir}\\physionet.org\\files\\ptbdb\\1.0.0')]

exception = ['OLS', 'tml', 'png', 'DME', 'ODS','txt']

it = 0
n = 1
for patient in patients:

    if patient in exception:
        continue
    if patient == '139':
        continue

    # Look for all the ecg files in one patient
    path_name = f'{wk_dir}\\physionet.org\\files\\ptbdb\\1.0.0\\patient{patient}'
    files = [file for file in os.listdir(path_name) if 'xyz' in file]
    files = np.unique(np.array([ file.split('.')[0] for file in files]))

    # Iterate over the ecg from one patient
    for i, file in enumerate(files):
        if file == 'index':
            continue

        if not (os.path.exists(f'{path_name}\\{file}.dat') and os.path.exists(f'{path_name}\\{file}.hea') and os.path.exists(f'{path_name}\\{file}.xyz')):
            continue

        print(f'Patient number {patient}, ecg number {i}')
        it += 1

        # Extract data
        # signal_i to find the qrs complex, derivation 1 is the one used in this algorithm
        # signal_ii to find peaks, the one the doctor wants to see
        file = f'{path_name}\\{file}'
        df, col_names = analyze_data.upload_data(file)
        signal_ecg_i = analyze_data.select_derivation(df, col_names, der='i')
        signal_ecg_ii = analyze_data.select_derivation(df, col_names, der='i')

        # Create object to find all features in an ecg
        wave_feat = ecg_features.ecg_wave(fs, signal_ecg_i, signal_ecg_ii)
        wave_feat.main_properties( fs=fs, t_qrs_min=time_min_qrs,  t_ref=refractor_time, th_grad=0.08, plot = False)

        if type(wave_feat.periods) == bool:
            wave_feat.ecg_fix()

        # apply the algorithm available in neurokit2 library to the same signal
        _, rpeaks = nk.ecg_peaks(signal_ecg_i, sampling_rate=1000)
        rpeaks_ind = rpeaks['ECG_R_Peaks']

        # Add values into the dataframe
        dic = {'patient':patient[-3:], 'heart_rate':wave_feat.heart_rate, 'periodicity':wave_feat.periodic_beat, 'variability':wave_feat.variability_beat, 'num_beats' :len(wave_feat.r_peaks_ind)+2,'num beat neurokit2': len(rpeaks_ind)}
        df_now = pd.DataFrame.from_records([dic])
        df_save = pd.concat([df_save,df_now])

        if (it == 30*n or patient == '294'):
            df_save.to_csv(f'{wk_dir}\\ecg_features_v12.csv')
            n +=1
# Out:
# Patient number 001, ecg number 0
#
#  Heart rate = 82.8125 (beats/min)
# Heart rate periodicity = 0.7335 (mean seconds between beats)
# Heart rate variability = 0.00920271699010679 (std seconds between beats)
# Patient number 001, ecg number 1
#
#  Heart rate = 86.45833333333333 (beats/min)
# Heart rate periodicity = 0.6956257668711657 (mean seconds between beats)
# Heart rate variability = 0.005270692076383867 (std seconds between beats)
# Patient number 001, ecg number 2
#
#  Heart rate = 80.20833333333333 (beats/min)
# Heart rate periodicity = 0.7513774834437086 (mean seconds between beats)
# Heart rate variability = 0.00972383003184119 (std seconds between beats)
# Patient number 002, ecg number 0
#
#  Heart rate = 79.16666666666667 (beats/min)
# Heart rate periodicity = 0.760744966442953 (mean seconds between beats)
# Heart rate variability = 0.02103054804738505 (std seconds between beats)
# Patient number 003, ecg number 0
#
#  Heart rate = 72.39583333333333 (beats/min)
# Heart rate periodicity = 0.8300882352941176 (mean seconds between beats)
# Heart rate variability = 0.022759765385768453 (std seconds between beats)
# Patient number 004, ecg number 0
#
#  Heart rate = 82.8125 (beats/min)
# Heart rate periodicity = 0.7269551282051282 (mean seconds between beats)
# Heart rate variability = 0.012144083158180134 (std seconds between beats)
# Patient number 004, ecg number 1
#
#  Heart rate = 81.77083333333333 (beats/min)
# Heart rate periodicity = 0.7407987012987013 (mean seconds between beats)
# Heart rate variability = 0.010490180857224113 (std seconds between beats)
# Patient number 005, ecg number 0
#
#  Heart rate = 96.3759181759772 (beats/min)
# Heart rate periodicity = 0.623934065934066 (mean seconds between beats)
# Heart rate variability = 0.05041014249023467 (std seconds between beats)
# Patient number 005, ecg number 1
#
#  Heart rate = 95.85496726691788 (beats/min)
# Heart rate periodicity = 0.6295082872928177 (mean seconds between beats)
# Heart rate variability = 0.06007643554769505 (std seconds between beats)
# Patient number 005, ecg number 2
#
#  Heart rate = 103.64583333333333 (beats/min)
# Heart rate periodicity = 0.5811326530612245 (mean seconds between beats)
# Heart rate variability = 0.03704152048580136 (std seconds between beats)
# Patient number 005, ecg number 3
#
#  Heart rate = 87.5 (beats/min)
# Heart rate periodicity = 0.6894242424242424 (mean seconds between beats)
# Heart rate variability = 0.15573618530163394 (std seconds between beats)
# Patient number 005, ecg number 4
#
#  Heart rate = 27.604166666666664 (beats/min)
# Heart rate periodicity = 2.12298 (mean seconds between beats)
# Heart rate variability = 2.516214263452141 (std seconds between beats)
# Patient number 006, ecg number 0
#
#  Heart rate = 92.20831090350252 (beats/min)
# Heart rate periodicity = 0.6528103448275862 (mean seconds between beats)
# Heart rate variability = 0.021579942446008717 (std seconds between beats)
# Patient number 006, ecg number 1
#
#  Heart rate = 81.25 (beats/min)
# Heart rate periodicity = 0.742797385620915 (mean seconds between beats)
# Heart rate variability = 0.015262992741051423 (std seconds between beats)
# Patient number 006, ecg number 2
#
#  Heart rate = 78.125 (beats/min)
# Heart rate periodicity = 0.7713129251700681 (mean seconds between beats)
# Heart rate variability = 0.032248567488321445 (std seconds between beats)
# Patient number 007, ecg number 0
#
#  Heart rate = 74.47916666666667 (beats/min)
# Heart rate periodicity = 0.80915 (mean seconds between beats)
# Heart rate variability = 0.023802138259288494 (std seconds between beats)
# Patient number 007, ecg number 1
#
#  Heart rate = 71.35416666666667 (beats/min)
# Heart rate periodicity = 0.8424552238805971 (mean seconds between beats)
# Heart rate variability = 0.030168584943400807 (std seconds between beats)
# Patient number 007, ecg number 2
#
#  Heart rate = 68.75 (beats/min)
# Heart rate periodicity = 0.8764961240310079 (mean seconds between beats)
# Heart rate variability = 0.03476635726359559 (std seconds between beats)
# Patient number 007, ecg number 3
#
#  Heart rate = 53.64583333333333 (beats/min)
# Heart rate periodicity = 1.12953 (mean seconds between beats)
# Heart rate variability = 0.05591143979544795 (std seconds between beats)
# Patient number 008, ecg number 0
#
#  Heart rate = 59.89583333333333 (beats/min)
# Heart rate periodicity = 1.0119375 (mean seconds between beats)
# Heart rate variability = 0.08584738131978334 (std seconds between beats)
# Patient number 008, ecg number 1
#
#  Heart rate = 64.58333333333333 (beats/min)
# Heart rate periodicity = 0.9358677685950414 (mean seconds between beats)
# Heart rate variability = 0.03249817341307234 (std seconds between beats)
# Patient number 008, ecg number 2
#
#  Heart rate = 59.89583333333333 (beats/min)
# Heart rate periodicity = 1.0053125 (mean seconds between beats)
# Heart rate variability = 0.11030178013474153 (std seconds between beats)
# Patient number 009, ecg number 0
#
#  Heart rate = 88.125 (beats/min)
# Heart rate periodicity = 0.7008863636363638 (mean seconds between beats)
# Heart rate variability = 0.010364309188685805 (std seconds between beats)
# Patient number 010, ecg number 0
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 010, ecg number 1
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 010, ecg number 2
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 011, ecg number 0
#
#  Heart rate = 91.14583333333333 (beats/min)
# Heart rate periodicity = 0.6635058139534885 (mean seconds between beats)
# Heart rate variability = 0.013922333193354567 (std seconds between beats)
# Patient number 011, ecg number 1
#
#  Heart rate = 79.16666666666667 (beats/min)
# Heart rate periodicity = 0.7631073825503356 (mean seconds between beats)
# Heart rate variability = 0.07535705975928905 (std seconds between beats)
# Patient number 011, ecg number 2
#
#  Heart rate = 88.54166666666667 (beats/min)
# Heart rate periodicity = 0.6786886227544909 (mean seconds between beats)
# Heart rate variability = 0.014022609711930766 (std seconds between beats)
# Patient number 011, ecg number 3
#
#  Heart rate = 67.5 (beats/min)
# Heart rate periodicity = 0.9037272727272727 (mean seconds between beats)
# Heart rate variability = 0.026733559351352507 (std seconds between beats)
# Patient number 012, ecg number 0
#
#  Heart rate = 53.125 (beats/min)
# Heart rate periodicity = 1.14679797979798 (mean seconds between beats)
# Heart rate variability = 0.036041496790065165 (std seconds between beats)
# Patient number 012, ecg number 1
#
#  Heart rate = 63.541666666666664 (beats/min)
# Heart rate periodicity = 0.9459495798319327 (mean seconds between beats)
# Heart rate variability = 0.016327452131326838 (std seconds between beats)
# Patient number 013, ecg number 0
#
#  Heart rate = 85.9375 (beats/min)
# Heart rate periodicity = 0.7031790123456789 (mean seconds between beats)
# Heart rate variability = 0.005363231383819868 (std seconds between beats)
# Patient number 013, ecg number 1
#
#  Heart rate = 83.33333333333333 (beats/min)
# Heart rate periodicity = 0.7227388535031847 (mean seconds between beats)
# Heart rate variability = 0.011075391035247203 (std seconds between beats)
# Patient number 013, ecg number 2
#
#  Heart rate = 89.0625 (beats/min)
# Heart rate periodicity = 0.6768452380952381 (mean seconds between beats)
# Heart rate variability = 0.008165686113561768 (std seconds between beats)
# Patient number 014, ecg number 1
#
#  Heart rate = 75.52083333333333 (beats/min)
# Heart rate periodicity = 0.7951901408450704 (mean seconds between beats)
# Heart rate variability = 0.03827291417092632 (std seconds between beats)
# Patient number 014, ecg number 2
#
#  Heart rate = 80.20833333333333 (beats/min)
# Heart rate periodicity = 0.7498013245033113 (mean seconds between beats)
# Heart rate variability = 0.015088708934780962 (std seconds between beats)
# Patient number 015, ecg number 0
#
#  Heart rate = 115.10416666666666 (beats/min)
# Heart rate periodicity = 0.5222752293577982 (mean seconds between beats)
# Heart rate variability = 0.005460234157752465 (std seconds between beats)
# Patient number 015, ecg number 1
#
#  Heart rate = 82.8125 (beats/min)
# Heart rate periodicity = 0.7253910256410256 (mean seconds between beats)
# Heart rate variability = 0.009315395113871866 (std seconds between beats)
# Patient number 015, ecg number 2
#
#  Heart rate = 67.1875 (beats/min)
# Heart rate periodicity = 0.8974603174603174 (mean seconds between beats)
# Heart rate variability = 0.025997756555729303 (std seconds between beats)
# Patient number 016, ecg number 0
#
#  Heart rate = 59.375 (beats/min)
# Heart rate periodicity = 1.0152972972972976 (mean seconds between beats)
# Heart rate variability = 0.021465494873700797 (std seconds between beats)
# Patient number 016, ecg number 1
#
#  Heart rate = 73.4375 (beats/min)
# Heart rate periodicity = 0.8216231884057972 (mean seconds between beats)
# Heart rate variability = 0.026198297018044166 (std seconds between beats)
# Patient number 016, ecg number 2
#
#  Heart rate = 57.291666666666664 (beats/min)
# Heart rate periodicity = 1.055859813084112 (mean seconds between beats)
# Heart rate variability = 0.01637381577262052 (std seconds between beats)
# Patient number 017, ecg number 0
#
#  Heart rate = 93.75 (beats/min)
# Heart rate periodicity = 0.6426384180790962 (mean seconds between beats)
# Heart rate variability = 0.020746091968387777 (std seconds between beats)
# Patient number 017, ecg number 1
#
#  Heart rate = 60.416666666666664 (beats/min)
# Heart rate periodicity = 0.9963628318584072 (mean seconds between beats)
# Heart rate variability = 0.04085655068129832 (std seconds between beats)
# Patient number 017, ecg number 2
#
#  Heart rate = 80.72916666666667 (beats/min)
# Heart rate periodicity = 0.7489013157894737 (mean seconds between beats)
# Heart rate variability = 0.03581086277940733 (std seconds between beats)
# Patient number 017, ecg number 3
#
#  Heart rate = 63.541666666666664 (beats/min)
# Heart rate periodicity = 0.9528487394957983 (mean seconds between beats)
# Heart rate variability = 0.021871910789969987 (std seconds between beats)
# Patient number 018, ecg number 0
#
#  Heart rate = 88.02083333333333 (beats/min)
# Heart rate periodicity = 0.6853433734939759 (mean seconds between beats)
# Heart rate variability = 0.1301649423428811 (std seconds between beats)
# Patient number 018, ecg number 1
#
#  Heart rate = 78.64583333333333 (beats/min)
# Heart rate periodicity = 0.7683310810810811 (mean seconds between beats)
# Heart rate variability = 0.02399053544052647 (std seconds between beats)
# Patient number 018, ecg number 2
#
#  Heart rate = 69.79166666666667 (beats/min)
# Heart rate periodicity = 0.8599694656488549 (mean seconds between beats)
# Heart rate variability = 0.018536095972802424 (std seconds between beats)
# Patient number 019, ecg number 0
#
#  Heart rate = 88.02083333333333 (beats/min)
# Heart rate periodicity = 0.6833915662650604 (mean seconds between beats)
# Heart rate variability = 0.01859484774358355 (std seconds between beats)
# Patient number 019, ecg number 1
#
#  Heart rate = 85.9375 (beats/min)
# Heart rate periodicity = 0.6989691358024692 (mean seconds between beats)
# Heart rate variability = 0.02549713681323679 (std seconds between beats)
# Patient number 019, ecg number 2
#
#  Heart rate = 73.95833333333333 (beats/min)
# Heart rate periodicity = 0.8158057553956835 (mean seconds between beats)
# Heart rate variability = 0.06635417046500124 (std seconds between beats)
# Patient number 020, ecg number 0
#
#  Heart rate = 65.10416666666667 (beats/min)
# Heart rate periodicity = 0.9262868852459017 (mean seconds between beats)
# Heart rate variability = 0.03742127901455525 (std seconds between beats)
# Patient number 020, ecg number 1
#
#  Heart rate = 51.5625 (beats/min)
# Heart rate periodicity = 1.1739895833333334 (mean seconds between beats)
# Heart rate variability = 0.05446357628262263 (std seconds between beats)
# Patient number 020, ecg number 2
#
#  Heart rate = 70.83333333333333 (beats/min)
# Heart rate periodicity = 0.8536917293233083 (mean seconds between beats)
# Heart rate variability = 0.07067208831592747 (std seconds between beats)
# Patient number 021, ecg number 0
#
#  Heart rate = 74.47916666666667 (beats/min)
# Heart rate periodicity = 0.8083142857142858 (mean seconds between beats)
# Heart rate variability = 0.08872140068087017 (std seconds between beats)
# Patient number 021, ecg number 1
#
#  Heart rate = 91.66666666666667 (beats/min)
# Heart rate periodicity = 0.6567456647398844 (mean seconds between beats)
# Heart rate variability = 0.11275849709080298 (std seconds between beats)
# Patient number 021, ecg number 2
#
#  Heart rate = 92.1875 (beats/min)
# Heart rate periodicity = 0.6521781609195402 (mean seconds between beats)
# Heart rate variability = 0.07516814396991689 (std seconds between beats)
# Patient number 022, ecg number 0
#
#  Heart rate = 66.14583333333333 (beats/min)
# Heart rate periodicity = 0.9165645161290323 (mean seconds between beats)
# Heart rate variability = 0.02407054214095349 (std seconds between beats)
# Patient number 022, ecg number 1
#
#  Heart rate = 65.52155613695825 (beats/min)
# Heart rate periodicity = 0.9251935483870967 (mean seconds between beats)
# Heart rate variability = 0.024696113517977278 (std seconds between beats)
# Patient number 022, ecg number 2
#
#  Heart rate = 68.22916666666667 (beats/min)
# Heart rate periodicity = 0.8846093749999999 (mean seconds between beats)
# Heart rate variability = 0.03808014459149776 (std seconds between beats)
# Patient number 023, ecg number 0
#
#  Heart rate = 67.1875 (beats/min)
# Heart rate periodicity = 0.8961190476190478 (mean seconds between beats)
# Heart rate variability = 0.17965322006147857 (std seconds between beats)
# Patient number 023, ecg number 1
#
#  Heart rate = 67.70833333333333 (beats/min)
# Heart rate periodicity = 0.8912362204724407 (mean seconds between beats)
# Heart rate variability = 0.2567140465190858 (std seconds between beats)
# Patient number 023, ecg number 2
#
#  Heart rate = 55.729166666666664 (beats/min)
# Heart rate periodicity = 1.0758173076923077 (mean seconds between beats)
# Heart rate variability = 0.3122255337591931 (std seconds between beats)
# Patient number 023, ecg number 3
#
#  Heart rate = 55.729166666666664 (beats/min)
# Heart rate periodicity = 1.0928076923076924 (mean seconds between beats)
# Heart rate variability = 0.2575468619390936 (std seconds between beats)
# Patient number 024, ecg number 0
#
#  Heart rate = 64.0625 (beats/min)
# Heart rate periodicity = 0.9419833333333334 (mean seconds between beats)
# Heart rate variability = 0.020488201211645893 (std seconds between beats)
# Patient number 024, ecg number 1
#
#  Heart rate = 65.625 (beats/min)
# Heart rate periodicity = 0.9203577235772359 (mean seconds between beats)
# Heart rate variability = 0.02178055001705748 (std seconds between beats)
# Patient number 024, ecg number 2
#
#  Heart rate = 78.64583333333333 (beats/min)
# Heart rate periodicity = 0.7686081081081081 (mean seconds between beats)
# Heart rate variability = 0.015692413012359675 (std seconds between beats)
# Patient number 025, ecg number 0
#
#  Heart rate = 74.47916666666667 (beats/min)
# Heart rate periodicity = 0.8117714285714287 (mean seconds between beats)
# Heart rate variability = 0.1584532081835943 (std seconds between beats)
# Patient number 025, ecg number 1
#
#  Heart rate = 56.77083333333333 (beats/min)
# Heart rate periodicity = 1.0635660377358491 (mean seconds between beats)
# Heart rate variability = 0.5252509376724709 (std seconds between beats)
# Patient number 025, ecg number 2
#
#  Heart rate = 66.66666666666667 (beats/min)
# Heart rate periodicity = 0.8983519999999999 (mean seconds between beats)
# Heart rate variability = 0.3316365542216358 (std seconds between beats)
# Patient number 026, ecg number 0
#
#  Heart rate = 75.0 (beats/min)
# Heart rate periodicity = 0.8026524822695036 (mean seconds between beats)
# Heart rate variability = 0.0091108117641327 (std seconds between beats)
# Patient number 026, ecg number 1
#
#  Heart rate = 78.125 (beats/min)
# Heart rate periodicity = 0.7683401360544218 (mean seconds between beats)
# Heart rate variability = 0.021899428936312294 (std seconds between beats)
# Patient number 027, ecg number 0
#
#  Heart rate = 98.4375 (beats/min)
# Heart rate periodicity = 0.6076612903225806 (mean seconds between beats)
# Heart rate variability = 0.17562725774449475 (std seconds between beats)
# Patient number 027, ecg number 1
#
#  Heart rate = 111.97916666666666 (beats/min)
# Heart rate periodicity = 0.5376132075471698 (mean seconds between beats)
# Heart rate variability = 0.06416305448940031 (std seconds between beats)
# Patient number 027, ecg number 2
#
#  Heart rate = 33.333333333333336 (beats/min)
# Heart rate periodicity = 1.8498032786885246 (mean seconds between beats)
# Heart rate variability = 1.7416265039707892 (std seconds between beats)
# Patient number 028, ecg number 0
#
#  Heart rate = 59.375 (beats/min)
# Heart rate periodicity = 1.0159459459459461 (mean seconds between beats)
# Heart rate variability = 0.02321689266862099 (std seconds between beats)
# Patient number 028, ecg number 1
#
#  Heart rate = 54.6875 (beats/min)
# Heart rate periodicity = 1.1093529411764707 (mean seconds between beats)
# Heart rate variability = 0.06511869209356812 (std seconds between beats)
# Patient number 028, ecg number 2
#
#  Heart rate = 50.0 (beats/min)
# Heart rate periodicity = 1.20952688172043 (mean seconds between beats)
# Heart rate variability = 0.058729119629250974 (std seconds between beats)
# Patient number 029, ecg number 0
#
#  Heart rate = 97.91666666666666 (beats/min)
# Heart rate periodicity = 0.6164864864864865 (mean seconds between beats)
# Heart rate variability = 0.015213830161920558 (std seconds between beats)
# Patient number 029, ecg number 1
#
#  Heart rate = 85.41666666666667 (beats/min)
# Heart rate periodicity = 0.7052919254658385 (mean seconds between beats)
# Heart rate variability = 0.021186436464903678 (std seconds between beats)
# Patient number 029, ecg number 2
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 030, ecg number 0
#
#  Heart rate = 76.04166666666667 (beats/min)
# Heart rate periodicity = 0.7961888111888111 (mean seconds between beats)
# Heart rate variability = 0.3470376926999873 (std seconds between beats)
# Patient number 030, ecg number 1
#
#  Heart rate = 57.8125 (beats/min)
# Heart rate periodicity = 1.0517685185185184 (mean seconds between beats)
# Heart rate variability = 0.0945535911613563 (std seconds between beats)
# Patient number 030, ecg number 2
#
#  Heart rate = 57.291666666666664 (beats/min)
# Heart rate periodicity = 1.0627009345794394 (mean seconds between beats)
# Heart rate variability = 0.06614459026675173 (std seconds between beats)
# Patient number 030, ecg number 3
#
#  Heart rate = 74.47916666666667 (beats/min)
# Heart rate periodicity = 0.8107000000000001 (mean seconds between beats)
# Heart rate variability = 0.07550446533625865 (std seconds between beats)
# Patient number 031, ecg number 0
#
#  Heart rate = 94.27083333333333 (beats/min)
# Heart rate periodicity = 0.6375730337078651 (mean seconds between beats)
# Heart rate variability = 0.006365086723593313 (std seconds between beats)
# Patient number 031, ecg number 1
#
#  Heart rate = 88.54166666666667 (beats/min)
# Heart rate periodicity = 0.6825329341317365 (mean seconds between beats)
# Heart rate variability = 0.007611671176388131 (std seconds between beats)
# Patient number 031, ecg number 2
#
#  Heart rate = 90.625 (beats/min)
# Heart rate periodicity = 0.6652982456140352 (mean seconds between beats)
# Heart rate variability = 0.010420343764655372 (std seconds between beats)
# Patient number 031, ecg number 3
#
#  Heart rate = 77.60416666666667 (beats/min)
# Heart rate periodicity = 0.7796780821917809 (mean seconds between beats)
# Heart rate variability = 0.011677712604122334 (std seconds between beats)
# Patient number 032, ecg number 0
#
#  Heart rate = 101.5625 (beats/min)
# Heart rate periodicity = 0.5929322916666666 (mean seconds between beats)
# Heart rate variability = 0.009867908791376752 (std seconds between beats)
# Patient number 032, ecg number 1
#
#  Heart rate = 89.58333333333333 (beats/min)
# Heart rate periodicity = 0.6710118343195267 (mean seconds between beats)
# Heart rate variability = 0.008968708366948202 (std seconds between beats)
# Patient number 032, ecg number 2
#
#  Heart rate = 77.60416666666667 (beats/min)
# Heart rate periodicity = 0.7759178082191781 (mean seconds between beats)
# Heart rate variability = 0.011859050557595407 (std seconds between beats)
# Patient number 032, ecg number 3
#
#  Heart rate = 83.85416666666667 (beats/min)
# Heart rate periodicity = 0.7188987341772151 (mean seconds between beats)
# Heart rate variability = 0.009271700425350218 (std seconds between beats)
# Patient number 033, ecg number 0
#
#  Heart rate = 78.64583333333333 (beats/min)
# Heart rate periodicity = 0.7650067567567568 (mean seconds between beats)
# Heart rate variability = 0.012864941162049486 (std seconds between beats)
# Patient number 033, ecg number 1
#
#  Heart rate = 64.58333333333333 (beats/min)
# Heart rate periodicity = 0.9363305785123968 (mean seconds between beats)
# Heart rate variability = 0.010847087760706272 (std seconds between beats)
# Patient number 033, ecg number 2
#
#  Heart rate = 61.45833333333333 (beats/min)
# Heart rate periodicity = 0.9846260869565218 (mean seconds between beats)
# Heart rate variability = 0.02153115472561854 (std seconds between beats)
# Patient number 033, ecg number 3
#
#  Heart rate = 58.854166666666664 (beats/min)
# Heart rate periodicity = 1.0276454545454545 (mean seconds between beats)
# Heart rate variability = 0.013825264333252244 (std seconds between beats)
# Patient number 034, ecg number 0
#
#  Heart rate = 121.875 (beats/min)
# Heart rate periodicity = 0.4924199134199134 (mean seconds between beats)
# Heart rate variability = 0.00593261890669467 (std seconds between beats)
# Patient number 034, ecg number 2
#
#  Heart rate = 85.41666666666667 (beats/min)
# Heart rate periodicity = 0.7060807453416149 (mean seconds between beats)
# Heart rate variability = 0.007575684504898372 (std seconds between beats)
# Patient number 034, ecg number 3
#
#  Heart rate = 77.60416666666667 (beats/min)
# Heart rate periodicity = 0.7749657534246576 (mean seconds between beats)
# Heart rate variability = 0.023400449118615222 (std seconds between beats)
# Patient number 035, ecg number 0
#
#  Heart rate = 91.14583333333333 (beats/min)
# Heart rate periodicity = 0.6613662790697675 (mean seconds between beats)
# Heart rate variability = 0.011250820233303893 (std seconds between beats)
# Patient number 035, ecg number 1
#
#  Heart rate = 86.45833333333333 (beats/min)
# Heart rate periodicity = 0.6976687116564417 (mean seconds between beats)
# Heart rate variability = 0.01264816736147865 (std seconds between beats)
# Patient number 035, ecg number 2
#
#  Heart rate = 94.27083333333333 (beats/min)
# Heart rate periodicity = 0.6403202247191011 (mean seconds between beats)
# Heart rate variability = 0.007104653954603979 (std seconds between beats)
# Patient number 035, ecg number 3
#
#  Heart rate = 88.02083333333333 (beats/min)
# Heart rate periodicity = 0.6827951807228916 (mean seconds between beats)
# Heart rate variability = 0.009170091558114718 (std seconds between beats)
# Patient number 036, ecg number 0
#
#  Heart rate = 74.47916666666667 (beats/min)
# Heart rate periodicity = 0.807207142857143 (mean seconds between beats)
# Heart rate variability = 0.015031631614019552 (std seconds between beats)
# Patient number 036, ecg number 1
#
#  Heart rate = 74.47916666666667 (beats/min)
# Heart rate periodicity = 0.812807142857143 (mean seconds between beats)
# Heart rate variability = 0.039878009770615515 (std seconds between beats)
# Patient number 036, ecg number 2
#
#  Heart rate = 73.4375 (beats/min)
# Heart rate periodicity = 0.8241304347826087 (mean seconds between beats)
# Heart rate variability = 0.04506626780657416 (std seconds between beats)
# Patient number 037, ecg number 0
#
#  Heart rate = 72.91666666666667 (beats/min)
# Heart rate periodicity = 0.8322262773722627 (mean seconds between beats)
# Heart rate variability = 0.024793156785055007 (std seconds between beats)
# Patient number 037, ecg number 1
#
#  Heart rate = 69.27083333333333 (beats/min)
# Heart rate periodicity = 0.8727461538461538 (mean seconds between beats)
# Heart rate variability = 0.025834476528755007 (std seconds between beats)
# Patient number 038, ecg number 0
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 038, ecg number 1
#
#  Heart rate = 67.70833333333333 (beats/min)
# Heart rate periodicity = 0.8879212598425197 (mean seconds between beats)
# Heart rate variability = 0.04721647355310169 (std seconds between beats)
# Patient number 038, ecg number 2
#
#  Heart rate = 59.89583333333333 (beats/min)
# Heart rate periodicity = 1.0033125 (mean seconds between beats)
# Heart rate variability = 0.0513275599963467 (std seconds between beats)
# Patient number 039, ecg number 0
#
#  Heart rate = 89.0625 (beats/min)
# Heart rate periodicity = 0.6781666666666667 (mean seconds between beats)
# Heart rate variability = 0.08033424717915309 (std seconds between beats)
# Patient number 039, ecg number 1
#
#  Heart rate = 76.04166666666667 (beats/min)
# Heart rate periodicity = 0.7944825174825176 (mean seconds between beats)
# Heart rate variability = 0.0716443091739946 (std seconds between beats)
# Patient number 039, ecg number 2
#
#  Heart rate = 78.64583333333333 (beats/min)
# Heart rate periodicity = 0.7640067567567568 (mean seconds between beats)
# Heart rate variability = 0.17410394133039797 (std seconds between beats)
# Patient number 040, ecg number 0
#
#  Heart rate = 92.1875 (beats/min)
# Heart rate periodicity = 0.6536781609195402 (mean seconds between beats)
# Heart rate variability = 0.026863210005325076 (std seconds between beats)
# Patient number 040, ecg number 1
#
#  Heart rate = 75.52083333333333 (beats/min)
# Heart rate periodicity = 0.7983802816901409 (mean seconds between beats)
# Heart rate variability = 0.009430048163787662 (std seconds between beats)
# Patient number 040, ecg number 2
#
#  Heart rate = 70.3125 (beats/min)
# Heart rate periodicity = 0.8596136363636363 (mean seconds between beats)
# Heart rate variability = 0.014226867309549435 (std seconds between beats)
# Patient number 040, ecg number 3
#
#  Heart rate = 72.91666666666667 (beats/min)
# Heart rate periodicity = 0.8276423357664233 (mean seconds between beats)
# Heart rate variability = 0.01702327184548306 (std seconds between beats)
# Patient number 041, ecg number 0
#
#  Heart rate = 97.39583333333333 (beats/min)
# Heart rate periodicity = 0.6190597826086957 (mean seconds between beats)
# Heart rate variability = 0.016835576718099158 (std seconds between beats)
# Patient number 041, ecg number 1
#
#  Heart rate = 82.29166666666667 (beats/min)
# Heart rate periodicity = 0.7304774193548388 (mean seconds between beats)
# Heart rate variability = 0.14552008332668306 (std seconds between beats)
# Patient number 041, ecg number 2
#
#  Heart rate = 43.229166666666664 (beats/min)
# Heart rate periodicity = 1.390925 (mean seconds between beats)
# Heart rate variability = 1.091133582278082 (std seconds between beats)
# Patient number 041, ecg number 3
#
#  Heart rate = 86.45833333333333 (beats/min)
# Heart rate periodicity = 0.694638036809816 (mean seconds between beats)
# Heart rate variability = 0.019224480203393506 (std seconds between beats)
# Patient number 042, ecg number 0
#
#  Heart rate = 95.3125 (beats/min)
# Heart rate periodicity = 0.6347611111111111 (mean seconds between beats)
# Heart rate variability = 0.008290130604043515 (std seconds between beats)
# Patient number 042, ecg number 1
#
#  Heart rate = 91.66666666666667 (beats/min)
# Heart rate periodicity = 0.6549595375722543 (mean seconds between beats)
# Heart rate variability = 0.00784853609670652 (std seconds between beats)
# Patient number 042, ecg number 2
#
#  Heart rate = 76.04166666666667 (beats/min)
# Heart rate periodicity = 0.7929230769230768 (mean seconds between beats)
# Heart rate variability = 0.09123519724156554 (std seconds between beats)
# Patient number 042, ecg number 3
#
#  Heart rate = 69.79166666666667 (beats/min)
# Heart rate periodicity = 0.8664122137404581 (mean seconds between beats)
# Heart rate variability = 0.07443885448427733 (std seconds between beats)
# Patient number 043, ecg number 0
#
#  Heart rate = 85.9375 (beats/min)
# Heart rate periodicity = 0.7007592592592592 (mean seconds between beats)
# Heart rate variability = 0.0202599786587689 (std seconds between beats)
# Patient number 043, ecg number 1
#
#  Heart rate = 71.875 (beats/min)
# Heart rate periodicity = 0.8383555555555555 (mean seconds between beats)
# Heart rate variability = 0.04618424722086552 (std seconds between beats)
# Patient number 043, ecg number 2
#
#  Heart rate = 84.89583333333333 (beats/min)
# Heart rate periodicity = 0.70836875 (mean seconds between beats)
# Heart rate variability = 0.01591250368224621 (std seconds between beats)
# Patient number 044, ecg number 0
#
#  Heart rate = 93.75 (beats/min)
# Heart rate periodicity = 0.644858757062147 (mean seconds between beats)
# Heart rate variability = 0.007709217070081545 (std seconds between beats)
# Patient number 044, ecg number 2
#
#  Heart rate = 75.52083333333333 (beats/min)
# Heart rate periodicity = 0.7955281690140845 (mean seconds between beats)
# Heart rate variability = 0.1668930117635868 (std seconds between beats)
# Patient number 044, ecg number 3
#
#  Heart rate = 63.541666666666664 (beats/min)
# Heart rate periodicity = 0.937764705882353 (mean seconds between beats)
# Heart rate variability = 0.04662972433223308 (std seconds between beats)
# Patient number 045, ecg number 0
#
#  Heart rate = 107.8125 (beats/min)
# Heart rate periodicity = 0.5597450980392158 (mean seconds between beats)
# Heart rate variability = 0.004791099334550016 (std seconds between beats)
# Patient number 045, ecg number 1
#
#  Heart rate = 82.29166666666667 (beats/min)
# Heart rate periodicity = 0.7329354838709676 (mean seconds between beats)
# Heart rate variability = 0.07166613249887643 (std seconds between beats)
# Patient number 045, ecg number 2
#
#  Heart rate = 63.02083333333333 (beats/min)
# Heart rate periodicity = 0.9557542372881357 (mean seconds between beats)
# Heart rate variability = 0.1697810622307885 (std seconds between beats)
# Patient number 045, ecg number 3
#
#  Heart rate = 85.41666666666667 (beats/min)
# Heart rate periodicity = 0.7044906832298137 (mean seconds between beats)
# Heart rate variability = 0.019837888966914564 (std seconds between beats)
# Patient number 046, ecg number 0
#
#  Heart rate = 104.6875 (beats/min)
# Heart rate periodicity = 0.5758535353535353 (mean seconds between beats)
# Heart rate variability = 0.006595358225868969 (std seconds between beats)
# Patient number 046, ecg number 1
#
#  Heart rate = 99.47916666666666 (beats/min)
# Heart rate periodicity = 0.6036276595744681 (mean seconds between beats)
# Heart rate variability = 0.009336480774136085 (std seconds between beats)
# Patient number 046, ecg number 2
#
#  Heart rate = 90.10416666666667 (beats/min)
# Heart rate periodicity = 0.6694529411764706 (mean seconds between beats)
# Heart rate variability = 0.02916647183985022 (std seconds between beats)
# Patient number 046, ecg number 3
#
#  Heart rate = 76.5625 (beats/min)
# Heart rate periodicity = 0.7886805555555556 (mean seconds between beats)
# Heart rate variability = 0.022404319021172455 (std seconds between beats)
# Patient number 047, ecg number 0
#
#  Heart rate = 82.8125 (beats/min)
# Heart rate periodicity = 0.7278397435897437 (mean seconds between beats)
# Heart rate variability = 0.018125451999623732 (std seconds between beats)
# Patient number 047, ecg number 1
#
#  Heart rate = 76.04166666666667 (beats/min)
# Heart rate periodicity = 0.7930069930069931 (mean seconds between beats)
# Heart rate variability = 0.014575818898175115 (std seconds between beats)
# Patient number 047, ecg number 2
#
#  Heart rate = 56.77083333333333 (beats/min)
# Heart rate periodicity = 1.0639811320754717 (mean seconds between beats)
# Heart rate variability = 0.12514210647824633 (std seconds between beats)
# Patient number 048, ecg number 0
#
#  Heart rate = 97.91666666666666 (beats/min)
# Heart rate periodicity = 0.6153675675675676 (mean seconds between beats)
# Heart rate variability = 0.006169237284937832 (std seconds between beats)
# Patient number 048, ecg number 1
#
#  Heart rate = 80.20833333333333 (beats/min)
# Heart rate periodicity = 0.7528278145695364 (mean seconds between beats)
# Heart rate variability = 0.00636605400293342 (std seconds between beats)
# Patient number 048, ecg number 2
#
#  Heart rate = 70.3125 (beats/min)
# Heart rate periodicity = 0.8581060606060606 (mean seconds between beats)
# Heart rate variability = 0.20061172575082345 (std seconds between beats)
# Patient number 048, ecg number 3
#
#  Heart rate = 67.1875 (beats/min)
# Heart rate periodicity = 0.8998174603174602 (mean seconds between beats)
# Heart rate variability = 0.049391278838435075 (std seconds between beats)
# Patient number 049, ecg number 0
#
#  Heart rate = 77.60416666666667 (beats/min)
# Heart rate periodicity = 0.7787602739726028 (mean seconds between beats)
# Heart rate variability = 0.07719973248538722 (std seconds between beats)
# Patient number 049, ecg number 1
#
#  Heart rate = 77.08333333333333 (beats/min)
# Heart rate periodicity = 0.7860551724137932 (mean seconds between beats)
# Heart rate variability = 0.020596879345264354 (std seconds between beats)
# Patient number 049, ecg number 2
#
#  Heart rate = 65.625 (beats/min)
# Heart rate periodicity = 0.9253495934959349 (mean seconds between beats)
# Heart rate variability = 0.02932547485454431 (std seconds between beats)
# Patient number 049, ecg number 3
#
#  Heart rate = 72.91666666666667 (beats/min)
# Heart rate periodicity = 0.8265182481751825 (mean seconds between beats)
# Heart rate variability = 0.03799310390552955 (std seconds between beats)
# Patient number 050, ecg number 0
#
#  Heart rate = 79.16666666666667 (beats/min)
# Heart rate periodicity = 0.7588590604026845 (mean seconds between beats)
# Heart rate variability = 0.02850503785315458 (std seconds between beats)
# Patient number 050, ecg number 1
#
#  Heart rate = 66.66666666666667 (beats/min)
# Heart rate periodicity = 0.903432 (mean seconds between beats)
# Heart rate variability = 0.03080761879795323 (std seconds between beats)
# Patient number 050, ecg number 2
#
#  Heart rate = 68.75 (beats/min)
# Heart rate periodicity = 0.8775116279069768 (mean seconds between beats)
# Heart rate variability = 0.02447657202244781 (std seconds between beats)
# Patient number 050, ecg number 3
#
#  Heart rate = 66.14583333333333 (beats/min)
# Heart rate periodicity = 0.9147177419354837 (mean seconds between beats)
# Heart rate variability = 0.03603080234302021 (std seconds between beats)
# Patient number 051, ecg number 0
#
#  Heart rate = 92.70833333333333 (beats/min)
# Heart rate periodicity = 0.6500342857142859 (mean seconds between beats)
# Heart rate variability = 0.014845835257397823 (std seconds between beats)
# Patient number 051, ecg number 1
#
#  Heart rate = 55.20833333333333 (beats/min)
# Heart rate periodicity = 1.0950582524271844 (mean seconds between beats)
# Heart rate variability = 0.16887795473935013 (std seconds between beats)
# Patient number 051, ecg number 2
#
#  Heart rate = 56.25 (beats/min)
# Heart rate periodicity = 1.0746380952380952 (mean seconds between beats)
# Heart rate variability = 0.10911026522433288 (std seconds between beats)
# Patient number 051, ecg number 3
#
#  Heart rate = 67.1875 (beats/min)
# Heart rate periodicity = 0.8958333333333335 (mean seconds between beats)
# Heart rate variability = 0.21376892842951886 (std seconds between beats)
# Patient number 052, ecg number 0
#
#  Heart rate = 78.64583333333333 (beats/min)
# Heart rate periodicity = 0.7684729729729728 (mean seconds between beats)
# Heart rate variability = 0.027054361177617933 (std seconds between beats)
# Patient number 053, ecg number 0
#
#  Heart rate = 47.395833333333336 (beats/min)
# Heart rate periodicity = 1.2776477272727271 (mean seconds between beats)
# Heart rate variability = 0.8221271058520409 (std seconds between beats)
# Patient number 054, ecg number 0
#
#  Heart rate = 82.8125 (beats/min)
# Heart rate periodicity = 0.7247179487179487 (mean seconds between beats)
# Heart rate variability = 0.020619195336022744 (std seconds between beats)
# Patient number 054, ecg number 1
#
#  Heart rate = 89.58333333333333 (beats/min)
# Heart rate periodicity = 0.672792899408284 (mean seconds between beats)
# Heart rate variability = 0.02218184014958709 (std seconds between beats)
# Patient number 054, ecg number 2
#
#  Heart rate = 83.85416666666667 (beats/min)
# Heart rate periodicity = 0.7228354430379746 (mean seconds between beats)
# Heart rate variability = 0.023027463174365406 (std seconds between beats)
# Patient number 054, ecg number 3
#
#  Heart rate = 69.27083333333333 (beats/min)
# Heart rate periodicity = 0.8749461538461538 (mean seconds between beats)
# Heart rate variability = 0.03927698710410884 (std seconds between beats)
# Patient number 055, ecg number 0
#
#  Heart rate = 105.20833333333333 (beats/min)
# Heart rate periodicity = 0.5724321608040202 (mean seconds between beats)
# Heart rate variability = 0.057466303614464545 (std seconds between beats)
# Patient number 056, ecg number 0
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 057, ecg number 0
#
#  Heart rate = 73.95833333333333 (beats/min)
# Heart rate periodicity = 0.8189640287769785 (mean seconds between beats)
# Heart rate variability = 0.024788141186486444 (std seconds between beats)
# Patient number 058, ecg number 0
#
#  Heart rate = 80.72916666666667 (beats/min)
# Heart rate periodicity = 0.7459736842105262 (mean seconds between beats)
# Heart rate variability = 0.009386403498524836 (std seconds between beats)
# Patient number 059, ecg number 0
#
#  Heart rate = 88.02083333333333 (beats/min)
# Heart rate periodicity = 0.6819397590361447 (mean seconds between beats)
# Heart rate variability = 0.007011779069898669 (std seconds between beats)
# Patient number 060, ecg number 0
#
#  Heart rate = 86.45833333333333 (beats/min)
# Heart rate periodicity = 0.6983496932515338 (mean seconds between beats)
# Heart rate variability = 0.011453042964969547 (std seconds between beats)
# Patient number 061, ecg number 0
#
#  Heart rate = 83.85416666666667 (beats/min)
# Heart rate periodicity = 0.719867088607595 (mean seconds between beats)
# Heart rate variability = 0.02088761501809258 (std seconds between beats)
# Patient number 062, ecg number 0
#
#  Heart rate = 81.25 (beats/min)
# Heart rate periodicity = 0.7415294117647059 (mean seconds between beats)
# Heart rate variability = 0.064331866164671 (std seconds between beats)
# Patient number 063, ecg number 0
#
#  Heart rate = 72.91666666666667 (beats/min)
# Heart rate periodicity = 0.8313868613138686 (mean seconds between beats)
# Heart rate variability = 0.1018147199556022 (std seconds between beats)
# Patient number 064, ecg number 0
#
#  Heart rate = 90.625 (beats/min)
# Heart rate periodicity = 0.6667368421052632 (mean seconds between beats)
# Heart rate variability = 0.012493544039194006 (std seconds between beats)
# Patient number 065, ecg number 0
#
#  Heart rate = 66.66666666666667 (beats/min)
# Heart rate periodicity = 0.9033680000000001 (mean seconds between beats)
# Heart rate variability = 0.07906286470904024 (std seconds between beats)
# Patient number 065, ecg number 1
#
#  Heart rate = 72.91666666666667 (beats/min)
# Heart rate periodicity = 0.8276131386861315 (mean seconds between beats)
# Heart rate variability = 0.020187532531507957 (std seconds between beats)
# Patient number 065, ecg number 2
#
#  Heart rate = 70.83333333333333 (beats/min)
# Heart rate periodicity = 0.8550676691729323 (mean seconds between beats)
# Heart rate variability = 0.01486793769353956 (std seconds between beats)
# Patient number 065, ecg number 3
#
#  Heart rate = 54.6875 (beats/min)
# Heart rate periodicity = 1.106343137254902 (mean seconds between beats)
# Heart rate variability = 0.0365334912417975 (std seconds between beats)
# Patient number 066, ecg number 0
#
#  Heart rate = 78.125 (beats/min)
# Heart rate periodicity = 0.7699659863945578 (mean seconds between beats)
# Heart rate variability = 0.030727995825116646 (std seconds between beats)
# Patient number 066, ecg number 1
#
#  Heart rate = 70.3125 (beats/min)
# Heart rate periodicity = 0.8561818181818183 (mean seconds between beats)
# Heart rate variability = 0.016920410027008614 (std seconds between beats)
# Patient number 066, ecg number 2
#
#  Heart rate = 70.83333333333333 (beats/min)
# Heart rate periodicity = 0.8511278195488721 (mean seconds between beats)
# Heart rate variability = 0.013679144728702538 (std seconds between beats)
# Patient number 067, ecg number 0
#
#  Heart rate = 140.625 (beats/min)
# Heart rate periodicity = 0.42652808988764046 (mean seconds between beats)
# Heart rate variability = 0.0038455866653748674 (std seconds between beats)
# Patient number 067, ecg number 1
#
#  Heart rate = 91.14583333333333 (beats/min)
# Heart rate periodicity = 0.6621279069767443 (mean seconds between beats)
# Heart rate variability = 0.007531787692959214 (std seconds between beats)
# Patient number 067, ecg number 2
#
#  Heart rate = 62.5 (beats/min)
# Heart rate periodicity = 0.9666923076923075 (mean seconds between beats)
# Heart rate variability = 0.08749900722645215 (std seconds between beats)
# Patient number 068, ecg number 0
#
#  Heart rate = 88.54166666666667 (beats/min)
# Heart rate periodicity = 0.6792694610778444 (mean seconds between beats)
# Heart rate variability = 0.018556415720182098 (std seconds between beats)
# Patient number 069, ecg number 0
#
#  Heart rate = 61.979166666666664 (beats/min)
# Heart rate periodicity = 0.9738793103448274 (mean seconds between beats)
# Heart rate variability = 0.020448065068402358 (std seconds between beats)
# Patient number 069, ecg number 1
#
#  Heart rate = 66.14583333333333 (beats/min)
# Heart rate periodicity = 0.9092983870967742 (mean seconds between beats)
# Heart rate variability = 0.025465023399820055 (std seconds between beats)
# Patient number 069, ecg number 2
#
#  Heart rate = 63.541666666666664 (beats/min)
# Heart rate periodicity = 0.9471092436974792 (mean seconds between beats)
# Heart rate variability = 0.025946224257288736 (std seconds between beats)
# Patient number 069, ecg number 3
#
#  Heart rate = 60.416666666666664 (beats/min)
# Heart rate periodicity = 1.0010265486725665 (mean seconds between beats)
# Heart rate variability = 0.02233829212737592 (std seconds between beats)
# Patient number 070, ecg number 0
#
#  Heart rate = 80.72916666666667 (beats/min)
# Heart rate periodicity = 0.7478947368421052 (mean seconds between beats)
# Heart rate variability = 0.02171106857377036 (std seconds between beats)
# Patient number 071, ecg number 0
#
#  Heart rate = 63.02083333333333 (beats/min)
# Heart rate periodicity = 0.9564915254237287 (mean seconds between beats)
# Heart rate variability = 0.02957832055451466 (std seconds between beats)
# Patient number 072, ecg number 0
#
#  Heart rate = 85.41666666666667 (beats/min)
# Heart rate periodicity = 0.7068447204968944 (mean seconds between beats)
# Heart rate variability = 0.05853464854957702 (std seconds between beats)
# Patient number 072, ecg number 1
#
#  Heart rate = 59.375 (beats/min)
# Heart rate periodicity = 1.0134144144144144 (mean seconds between beats)
# Heart rate variability = 0.022976865948193058 (std seconds between beats)
# Patient number 072, ecg number 2
#
#  Heart rate = 58.33333333333333 (beats/min)
# Heart rate periodicity = 1.0392660550458714 (mean seconds between beats)
# Heart rate variability = 0.03339495160490905 (std seconds between beats)
# Patient number 072, ecg number 3
#
#  Heart rate = 62.5 (beats/min)
# Heart rate periodicity = 0.9659487179487177 (mean seconds between beats)
# Heart rate variability = 0.016503740137535004 (std seconds between beats)
# Patient number 073, ecg number 1
#
#  Heart rate = 71.35416666666667 (beats/min)
# Heart rate periodicity = 0.844865671641791 (mean seconds between beats)
# Heart rate variability = 0.015976097371869755 (std seconds between beats)
# Patient number 073, ecg number 2
#
#  Heart rate = 65.625 (beats/min)
# Heart rate periodicity = 0.9166016260162603 (mean seconds between beats)
# Heart rate variability = 0.011476904937724599 (std seconds between beats)
# Patient number 073, ecg number 3
#
#  Heart rate = 63.02083333333333 (beats/min)
# Heart rate periodicity = 0.958152542372881 (mean seconds between beats)
# Heart rate variability = 0.014246990237396628 (std seconds between beats)
# Patient number 074, ecg number 0
#
#  Heart rate = 110.41666666666666 (beats/min)
# Heart rate periodicity = 0.546645933014354 (mean seconds between beats)
# Heart rate variability = 0.10253905310509402 (std seconds between beats)
# Patient number 074, ecg number 1
#
#  Heart rate = 89.0625 (beats/min)
# Heart rate periodicity = 0.6768988095238095 (mean seconds between beats)
# Heart rate variability = 0.004071737491761237 (std seconds between beats)
# Patient number 074, ecg number 2
#
#  Heart rate = 83.85416666666667 (beats/min)
# Heart rate periodicity = 0.7202848101265822 (mean seconds between beats)
# Heart rate variability = 0.005260422772815723 (std seconds between beats)
# Patient number 074, ecg number 3
#
#  Heart rate = 71.875 (beats/min)
# Heart rate periodicity = 0.8401925925925926 (mean seconds between beats)
# Heart rate variability = 0.017107285126213755 (std seconds between beats)
# Patient number 075, ecg number 0
#
#  Heart rate = 86.45833333333333 (beats/min)
# Heart rate periodicity = 0.7008466257668713 (mean seconds between beats)
# Heart rate variability = 0.021459787711311355 (std seconds between beats)
# Patient number 075, ecg number 1
#
#  Heart rate = 71.875 (beats/min)
# Heart rate periodicity = 0.8400814814814814 (mean seconds between beats)
# Heart rate variability = 0.023547604062079668 (std seconds between beats)
# Patient number 075, ecg number 2
#
#  Heart rate = 68.22916666666667 (beats/min)
# Heart rate periodicity = 0.8862734375000001 (mean seconds between beats)
# Heart rate variability = 0.01845082774386001 (std seconds between beats)
# Patient number 075, ecg number 3
#
#  Heart rate = 78.125 (beats/min)
# Heart rate periodicity = 0.7675986394557822 (mean seconds between beats)
# Heart rate variability = 0.030584256290496888 (std seconds between beats)
# Patient number 076, ecg number 0
#
#  Heart rate = 101.04166666666666 (beats/min)
# Heart rate periodicity = 0.5962356020942409 (mean seconds between beats)
# Heart rate variability = 0.01071486658800469 (std seconds between beats)
# Patient number 076, ecg number 1
#
#  Heart rate = 95.83333333333333 (beats/min)
# Heart rate periodicity = 0.6313038674033149 (mean seconds between beats)
# Heart rate variability = 0.013626081444803909 (std seconds between beats)
# Patient number 076, ecg number 2
#
#  Heart rate = 2.6041666666666665 (beats/min)
# Heart rate periodicity = 7.1555 (mean seconds between beats)
# Heart rate variability = 2.1035 (std seconds between beats)
# Patient number 076, ecg number 3
#
#  Heart rate = 88.02083333333333 (beats/min)
# Heart rate periodicity = 0.6839518072289157 (mean seconds between beats)
# Heart rate variability = 0.011480107063076842 (std seconds between beats)
# Patient number 077, ecg number 0
#
#  Heart rate = 116.66666666666666 (beats/min)
# Heart rate periodicity = 0.5154208144796381 (mean seconds between beats)
# Heart rate variability = 0.005527334073588945 (std seconds between beats)
# Patient number 077, ecg number 1
#
#  Heart rate = 82.29166666666667 (beats/min)
# Heart rate periodicity = 0.7319483870967742 (mean seconds between beats)
# Heart rate variability = 0.03121513147309193 (std seconds between beats)
# Patient number 077, ecg number 2
#
#  Heart rate = 77.08333333333333 (beats/min)
# Heart rate periodicity = 0.7819862068965516 (mean seconds between beats)
# ...
# Patient number 239, ecg number 0
#
#  Heart rate = 79.4920507949205 (beats/min)
# Heart rate periodicity = 0.7579423076923077 (mean seconds between beats)
# Heart rate variability = 0.15558365053122797 (std seconds between beats)
# Patient number 240, ecg number 0
#
#  Heart rate = 78.4921507849215 (beats/min)
# Heart rate periodicity = 0.7715584415584416 (mean seconds between beats)
# Heart rate variability = 0.024138934173359983 (std seconds between beats)
# Patient number 241, ecg number 0
#
#  Heart rate = 58.76288659793814 (beats/min)
# Heart rate periodicity = 1.02725 (mean seconds between beats)
# Heart rate variability = 0.07209287865090361 (std seconds between beats)
# Patient number 241, ecg number 1
#
#  Heart rate = 55.994400559944005 (beats/min)
# Heart rate periodicity = 1.077348623853211 (mean seconds between beats)
# Heart rate variability = 0.07473186026370007 (std seconds between beats)
# Patient number 242, ecg number 0
#
#  Heart rate = 72.4927507249275 (beats/min)
# Heart rate periodicity = 0.8309084507042254 (mean seconds between beats)
# Heart rate variability = 0.04164164778192679 (std seconds between beats)
# Patient number 243, ecg number 0
#
#  Heart rate = 92.4907509249075 (beats/min)
# Heart rate periodicity = 0.650978021978022 (mean seconds between beats)
# Heart rate variability = 0.028236434269632096 (std seconds between beats)
# Patient number 244, ecg number 0
#
#  Heart rate = 74.99250074992501 (beats/min)
# Heart rate periodicity = 0.8036802721088436 (mean seconds between beats)
# Heart rate variability = 0.013440717098296251 (std seconds between beats)
# Patient number 245, ecg number 0
#
#  Heart rate = 77.992200779922 (beats/min)
# Heart rate periodicity = 0.7732941176470588 (mean seconds between beats)
# Heart rate variability = 0.02766722946579504 (std seconds between beats)
# Patient number 245, ecg number 1
#
#  Heart rate = 61.49385061493851 (beats/min)
# Heart rate periodicity = 0.981425 (mean seconds between beats)
# Heart rate variability = 0.11594486207532727 (std seconds between beats)
# Patient number 246, ecg number 0
#
#  Heart rate = 58.49415058494151 (beats/min)
# Heart rate periodicity = 1.0283508771929823 (mean seconds between beats)
# Heart rate variability = 0.031034780278742596 (std seconds between beats)
# Patient number 247, ecg number 0
#
#  Heart rate = 81.49185081491851 (beats/min)
# Heart rate periodicity = 0.7401687499999999 (mean seconds between beats)
# Heart rate variability = 0.060568166337090806 (std seconds between beats)
# Patient number 248, ecg number 0
#
#  Heart rate = 63.49365063493651 (beats/min)
# Heart rate periodicity = 0.9545967741935483 (mean seconds between beats)
# Heart rate variability = 0.026778036063173555 (std seconds between beats)
# Patient number 249, ecg number 0
#
#  Heart rate = 57.494250574942505 (beats/min)
# Heart rate periodicity = 1.0505892857142858 (mean seconds between beats)
# Heart rate variability = 0.02995191192664042 (std seconds between beats)
# Patient number 250, ecg number 0
#
#  Heart rate = 57.494250574942505 (beats/min)
# Heart rate periodicity = 1.0543571428571428 (mean seconds between beats)
# Heart rate variability = 0.03935707803987403 (std seconds between beats)
# Patient number 251, ecg number 0
#
#  Heart rate = 77.992200779922 (beats/min)
# Heart rate periodicity = 0.7744705882352941 (mean seconds between beats)
# Heart rate variability = 0.03352884989782641 (std seconds between beats)
# Patient number 251, ecg number 1
#
#  Heart rate = 77.992200779922 (beats/min)
# Heart rate periodicity = 0.7743071895424837 (mean seconds between beats)
# Heart rate variability = 0.03288806149400351 (std seconds between beats)
# Patient number 251, ecg number 2
#
#  Heart rate = 77.49225077492251 (beats/min)
# Heart rate periodicity = 0.7817631578947368 (mean seconds between beats)
# Heart rate variability = 0.03136997744284404 (std seconds between beats)
# Patient number 252, ecg number 0
#
#  Heart rate = 61.49385061493851 (beats/min)
# Heart rate periodicity = 0.9816416666666666 (mean seconds between beats)
# Heart rate variability = 0.04399522622462072 (std seconds between beats)
# Patient number 253, ecg number 0
#
#  Heart rate = 49.495050494950505 (beats/min)
# Heart rate periodicity = 1.2262083333333333 (mean seconds between beats)
# Heart rate variability = 0.2935479062502216 (std seconds between beats)
# Patient number 254, ecg number 0
#
#  Heart rate = 80.49195080491951 (beats/min)
# Heart rate periodicity = 0.7490189873417722 (mean seconds between beats)
# Heart rate variability = 0.19774710455781608 (std seconds between beats)
# Patient number 255, ecg number 0
#
#  Heart rate = 65.4934506549345 (beats/min)
# Heart rate periodicity = 0.9159609375000001 (mean seconds between beats)
# Heart rate variability = 0.024193362449669836 (std seconds between beats)
# Patient number 256, ecg number 0
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 257, ecg number 0
#
#  Heart rate = 69.4930506949305 (beats/min)
# Heart rate periodicity = 0.8697941176470588 (mean seconds between beats)
# Heart rate variability = 0.5033997376317859 (std seconds between beats)
# Patient number 258, ecg number 0
#
#  Heart rate = 56.4943505649435 (beats/min)
# Heart rate periodicity = 1.0756272727272729 (mean seconds between beats)
# Heart rate variability = 0.051409737155330475 (std seconds between beats)
# Patient number 259, ecg number 0
#
#  Heart rate = 58.994100589941006 (beats/min)
# Heart rate periodicity = 1.023504347826087 (mean seconds between beats)
# Heart rate variability = 0.05052478925163859 (std seconds between beats)
# Patient number 260, ecg number 0
#
#  Heart rate = 57.994200579942 (beats/min)
# Heart rate periodicity = 1.0399203539823008 (mean seconds between beats)
# Heart rate variability = 0.3445363728847546 (std seconds between beats)
# Patient number 261, ecg number 0
#
#  Heart rate = 63.49365063493651 (beats/min)
# Heart rate periodicity = 0.9493387096774193 (mean seconds between beats)
# Heart rate variability = 0.028487090199114513 (std seconds between beats)
# Patient number 262, ecg number 0
#
#  Heart rate = 62.493750624937505 (beats/min)
# Heart rate periodicity = 0.9686229508196722 (mean seconds between beats)
# Heart rate variability = 0.03139732886958892 (std seconds between beats)
# Patient number 263, ecg number 0
#
#  Heart rate = 76.4923507649235 (beats/min)
# Heart rate periodicity = 0.7845000000000001 (mean seconds between beats)
# Heart rate variability = 0.021742354978244664 (std seconds between beats)
# Patient number 264, ecg number 0
#
#  Heart rate = 62.493750624937505 (beats/min)
# Heart rate periodicity = 0.9640983606557377 (mean seconds between beats)
# Heart rate variability = 0.04970180091008768 (std seconds between beats)
# Patient number 265, ecg number 0
#
#  Heart rate = 61.99380061993801 (beats/min)
# Heart rate periodicity = 0.981404958677686 (mean seconds between beats)
# Heart rate variability = 0.013865098887027574 (std seconds between beats)
# Patient number 266, ecg number 0
#
#  Heart rate = 72.99270072992701 (beats/min)
# Heart rate periodicity = 0.8260000000000001 (mean seconds between beats)
# Heart rate variability = 0.02359358689681037 (std seconds between beats)
# Patient number 267, ecg number 0
#
#  Heart rate = 55.49445055494451 (beats/min)
# Heart rate periodicity = 1.092 (mean seconds between beats)
# Heart rate variability = 0.029675404456041218 (std seconds between beats)
# Patient number 268, ecg number 0
#
#  Heart rate = 67.49325067493251 (beats/min)
# Heart rate periodicity = 0.8888257575757574 (mean seconds between beats)
# Heart rate variability = 0.020191693541217463 (std seconds between beats)
# Patient number 269, ecg number 0
#
#  Heart rate = 59.494050594940504 (beats/min)
# Heart rate periodicity = 1.0132758620689657 (mean seconds between beats)
# Heart rate variability = 0.04483621269782299 (std seconds between beats)
# Patient number 270, ecg number 0
#
#  Heart rate = 68.4931506849315 (beats/min)
# Heart rate periodicity = 0.8749701492537314 (mean seconds between beats)
# Heart rate variability = 0.07480860556875728 (std seconds between beats)
# Patient number 271, ecg number 0
#
#  Heart rate = 56.99430056994301 (beats/min)
# Heart rate periodicity = 1.0605135135135135 (mean seconds between beats)
# Heart rate variability = 0.03309605590525934 (std seconds between beats)
# Patient number 272, ecg number 0
#
#  Heart rate = 66.993300669933 (beats/min)
# Heart rate periodicity = 0.8999923664122137 (mean seconds between beats)
# Heart rate variability = 0.04687835422025921 (std seconds between beats)
# Patient number 273, ecg number 0
#
#  Heart rate = 43.99560043995601 (beats/min)
# Heart rate periodicity = 1.3824352941176472 (mean seconds between beats)
# Heart rate variability = 0.03400534458298595 (std seconds between beats)
# Patient number 274, ecg number 0
#
#  Heart rate = 55.49445055494451 (beats/min)
# Heart rate periodicity = 1.090425925925926 (mean seconds between beats)
# Heart rate variability = 0.016317000736396088 (std seconds between beats)
# Patient number 275, ecg number 0
#
#  Heart rate = 78.99210078992101 (beats/min)
# Heart rate periodicity = 0.7598193548387097 (mean seconds between beats)
# Heart rate variability = 0.02482622727830571 (std seconds between beats)
# Patient number 276, ecg number 0
#
#  Heart rate = 76.992300769923 (beats/min)
# Heart rate periodicity = 0.7860993377483444 (mean seconds between beats)
# Heart rate variability = 0.022132279912628967 (std seconds between beats)
# Patient number 277, ecg number 0
#
#  Heart rate = 49.495050494950505 (beats/min)
# Heart rate periodicity = 1.2184479166666666 (mean seconds between beats)
# Heart rate variability = 0.06883765166917295 (std seconds between beats)
# Patient number 278, ecg number 0
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 278, ecg number 1
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 278, ecg number 2
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 279, ecg number 0
#
#  Heart rate = 51.99480051994801 (beats/min)
# Heart rate periodicity = 1.1599900990099012 (mean seconds between beats)
# Heart rate variability = 0.07463806995179344 (std seconds between beats)
# Patient number 279, ecg number 1
#
#  Heart rate = 46.995300469953 (beats/min)
# Heart rate periodicity = 1.2873626373626377 (mean seconds between beats)
# Heart rate variability = 0.07922974195734034 (std seconds between beats)
# Patient number 279, ecg number 2
#
#  Heart rate = 45.49545045495451 (beats/min)
# Heart rate periodicity = 1.3201818181818181 (mean seconds between beats)
# Heart rate variability = 0.0657997211679892 (std seconds between beats)
# Patient number 279, ecg number 3
#
#  Heart rate = 46.4953504649535 (beats/min)
# Heart rate periodicity = 1.3044444444444447 (mean seconds between beats)
# Heart rate variability = 0.06448360878912668 (std seconds between beats)
# Patient number 280, ecg number 0
#
#  Heart rate = 62.493750624937505 (beats/min)
# Heart rate periodicity = 0.965639344262295 (mean seconds between beats)
# Heart rate variability = 0.05925549923622231 (std seconds between beats)
# Patient number 281, ecg number 0
#
#  Heart rate = 75.4924507549245 (beats/min)
# Heart rate periodicity = 0.7995608108108109 (mean seconds between beats)
# Heart rate variability = 0.0315933251484737 (std seconds between beats)
# Patient number 282, ecg number 0
#
#  Heart rate = 4.999500049995 (beats/min)
# Heart rate periodicity = 14.841142857142858 (mean seconds between beats)
# Heart rate variability = 10.507966385129922 (std seconds between beats)
# Patient number 283, ecg number 0
#
#  Heart rate = 52.494750524947506 (beats/min)
# Heart rate periodicity = 1.1568235294117646 (mean seconds between beats)
# Heart rate variability = 0.15711488314348296 (std seconds between beats)
# Patient number 284, ecg number 0
#
#  Heart rate = 76.992300769923 (beats/min)
# Heart rate periodicity = 0.7800596026490068 (mean seconds between beats)
# Heart rate variability = 0.03241519384324415 (std seconds between beats)
# Patient number 284, ecg number 1
#
#  Heart rate = 75.99240075992401 (beats/min)
# Heart rate periodicity = 0.7964630872483222 (mean seconds between beats)
# Heart rate variability = 0.0423496984593328 (std seconds between beats)
# Patient number 284, ecg number 2
#
#  Heart rate = 71.49285071492851 (beats/min)
# Heart rate periodicity = 0.8423714285714284 (mean seconds between beats)
# Heart rate variability = 0.03125342103723385 (std seconds between beats)
# Patient number 285, ecg number 0
#
#  Heart rate = 0 (beats/min)
# Heart rate periodicity = 0 (mean seconds between beats)
# Heart rate variability = 0 (std seconds between beats)
# Patient number 286, ecg number 0
#
#  Heart rate = 77.992200779922 (beats/min)
# Heart rate periodicity = 0.7746993464052288 (mean seconds between beats)
# Heart rate variability = 0.20979420619698053 (std seconds between beats)
# Patient number 287, ecg number 0
#
#  Heart rate = 92.4907509249075 (beats/min)
# Heart rate periodicity = 0.6506208791208792 (mean seconds between beats)
# Heart rate variability = 0.08491905779770006 (std seconds between beats)
# Patient number 287, ecg number 1
#
#  Heart rate = 88.99110088991101 (beats/min)
# Heart rate periodicity = 0.6750285714285714 (mean seconds between beats)
# Heart rate variability = 0.08598195349333843 (std seconds between beats)
# Patient number 288, ecg number 0
#
#  Heart rate = 56.4943505649435 (beats/min)
# Heart rate periodicity = 1.0579818181818184 (mean seconds between beats)
# Heart rate variability = 0.3064828626921365 (std seconds between beats)
# Patient number 289, ecg number 0
#
#  Heart rate = 77.49225077492251 (beats/min)
# Heart rate periodicity = 0.7808157894736842 (mean seconds between beats)
# Heart rate variability = 0.006161661016478797 (std seconds between beats)
# Patient number 290, ecg number 0
#
#  Heart rate = 59.494050594940504 (beats/min)
# Heart rate periodicity = 1.010241379310345 (mean seconds between beats)
# Heart rate variability = 0.28260279242737973 (std seconds between beats)
# Patient number 291, ecg number 0
#
#  Heart rate = 84.99150084991501 (beats/min)
# Heart rate periodicity = 0.7073353293413173 (mean seconds between beats)
# Heart rate variability = 0.04806577464222751 (std seconds between beats)
# Patient number 292, ecg number 1
#
#  Heart rate = 107.48925107489251 (beats/min)
# Heart rate periodicity = 0.5613632075471698 (mean seconds between beats)
# Heart rate variability = 0.09777841316097168 (std seconds between beats)
# Patient number 293, ecg number 0
#
#  Heart rate = 36.496350364963504 (beats/min)
# Heart rate periodicity = 1.6587857142857143 (mean seconds between beats)
# Heart rate variability = 3.124123401133541 (std seconds between beats)
# Patient number 293, ecg number 1
#
#  Heart rate = 72.4927507249275 (beats/min)
# Heart rate periodicity = 0.834774647887324 (mean seconds between beats)
# Heart rate variability = 0.044157431921366314 (std seconds between beats)
# Patient number 294, ecg number 0
#
#  Heart rate = 74.99250074992501 (beats/min)
# Heart rate periodicity = 0.8049727891156464 (mean seconds between beats)
# Heart rate variability = 0.05946495516033653 (std seconds between beats)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [41], in <cell line: 10>()
#      17 # Look for all the ecg files in one patient
#      18 path_name = f'{wk_dir}\\physionet.org\\files\\ptbdb\\1.0.0\\patient{patient}'
# ---> 19 files = [file for file in os.listdir(path_name) if 'xyz' in file]
#      20 files = np.unique(np.array([ file.split('.')[0] for file in files]))
#      22 # Iterate over the ecg from one patient
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\escorihu\\Desktop\\ecg_signal_processing\\physionet.org\\files\\ptbdb\\1.0.0\\patientRDS'
